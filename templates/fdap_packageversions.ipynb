# %%
packages = ['seaborn',
            'pandas',
            'numpy',
            'yfinance',
            'statsmodels',
            'matplotlib',
            'pandas_datareader',
            'wrds',
            'notarealpackage']

for package in packages:
    try:
        mod = __import__(package)
        print(f"{package} package version: {mod.__version__}")
    except ImportError:
        print(f"{package} package is not installed.")

# %%
import yfinance as yf
import pandas as pd
import seaborn as sns

df = yf.download(["AAPL", "GOOG", "TSLA"], interval="1d", period="5y")
sns.displot(data=df["Adj Close"].pct_change().stack().reset_index(), x=0, col="Ticker")

# %%
import wrds

# %%
db = wrds.Connection(wrds_username="lcdstein")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/miniconda3/envs/fdap/lib/python3.11/site-packages/sqlalchemy/engine/base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~/miniconda3/envs/fdap/lib/python3.11/site-packages/sqlalchemy/engine/base.py:3302, in Engine.raw_connection(self)
#    3281 """Return a "raw" DBAPI connection from the connection pool.
#    3282
#    3283 The returned object is a proxied version of the DBAPI
#    (...)
#    3300
#    3301 """
# -> 3302 return self.pool.connect()
#
# File ~/miniconda3/envs/fdap/lib/python3.11/site-packages/sqlalchemy/pool/base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
# ...

# %%
df = db.get_table("crsp", "dsp500", columns=["caldt", "vwretd", "sprtrn"], date_cols=["caldt"], index_col=["caldt"])
df

# %%
db.close()
